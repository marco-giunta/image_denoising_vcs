# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('./loss/CAE_validation_loss', 'rb') as f:
    cae = pickle.load(f)

# %%
with open('./loss/VCAE_11_KL1_validation_loss', 'rb') as f:
    vcae = pickle.load(f)

# %%
with open('./loss/RESCAE_validation_loss', 'rb') as f:
    rescae = pickle.load(f)

# %%
with open('./loss/CAE_pl_validation_loss', 'rb') as f:
    pl = pickle.load(f)

# %%
with open('./loss/CAE_mpl_05_validation_loss', 'rb') as f:
    mpl05 = pickle.load(f)

# %%
with open('./loss/CAE_mpl_1_validation_loss', 'rb') as f:
    mpl1 = pickle.load(f)

# %%
plt.plot(cae)

# %%
plt.plot(cae[:16])

# %%
plt.plot(vcae)

# %%
plt.plot(cae[:15], label = 'cae')
plt.plot(vcae, label = 'vcae')
plt.plot(rescae, label = 'rescae')
plt.legend()
plt.title('test loss')
# Out:
# Text(0.5, 1.0, 'test loss')

# %%
plt.plot(cae[:15], label = 'cae')
#plt.plot(vcae, label = 'vcae')
plt.plot(rescae, label = 'rescae')
plt.legend()
plt.title('test loss')
plt.savefig('./loss/cae_rescae.pdf')

# %%
#plt.plot(cae[:15], label = 'cae')
plt.plot(vcae, label = 'vcae')
#plt.plot(rescae, label = 'rescae')
plt.legend()
plt.title('test loss')
plt.savefig('./loss/vcae.pdf')

# %%
plt.plot(pl, label = 'cae + pl')
plt.plot(mpl05, label = r'cae + mpl $\rho = 0.5$')
plt.plot(mpl1, label = r'cae + mpl $\rho = 1$')
plt.legend()
plt.title('test loss')
plt.savefig('./loss/cae_pl_mpl.pdf')
